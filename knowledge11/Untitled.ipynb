# %%
import os
os.getcwd()
# Out:
# '/SNS/snfs1/instruments/EQSANS/shared/codereview/esac/data_eqsans_exp'

# %%
os.chdir('/SNS/users/ccd/analysiswork/crease_ga/')

# %%
import numpy as np
import crease_ga as cga
import math
m = cga.Model(pop_number = 20,
              generations = 20,
              nloci = 5)
#detailed explanations are needed to describe what each value in shape params means
m.load_shape(shape='micelle')

m.load_iq('SDS_5mgmL_0p1M_20C_Iq.dat')
m.solve(output_dir='./',name='test_micelle2',needs_postprocess=False)
# Out:
# imported builtin shape micelle
#
# Restarting from gen #10
# individual 20/20Generation time: 2.513s
# Generation best fitness: 3.4216
# Generation gdm: 0.834
# Generation best parameters [[2.     0.6875 0.3125]]
# pc 0.6
# #crossovers 11
# pm 0.006
# #mutations 0
# individual 20/20Generation time: 2.513s
# Generation best fitness: 3.4257
# Generation gdm: 0.832
# Generation best parameters [[2.     0.6875 0.3125]]
# pc 0.6
# #crossovers 12
# pm 0.006
# #mutations 2
# individual 20/20Generation time: 2.530s
# Generation best fitness: 3.0330
# Generation gdm: 0.764
# Generation best parameters [[2.     0.6875 0.3125]]
# pc 0.6
# #crossovers 10
# pm 0.006
# #mutations 2
# individual 20/20Generation time: 3.386s
# Generation best fitness: 3.2255
# Generation gdm: 0.695
# Generation best parameters [[2.     0.6875 0.3125]]
# pc 0.6
# #crossovers 10
# pm 0.006
# #mutations 1
# individual 20/20Generation time: 2.572s
# Generation best fitness: 3.4417
# Generation gdm: 0.821
# ...
